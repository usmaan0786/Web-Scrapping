# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen

site= "http://www.goibibo.com/hotels-international/hotels-in-dubai-ct/"
hdr = {'User-Agent': 'Mozilla/5.0'}
req = Request(site,headers=hdr)
page = urlopen(req)
data = BeautifulSoup(page, 'html.parser')
print(data)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script>
#           var starttime = new Date();
#         </script>
# <title data-react-helmet="true">Hotels in Dubai, 1863 Dubai Hotels from ₹1163 + upto 30% off</title>
# <meta content="#2d67b2" data-react-helmet="true" name="theme-color"/><meta content="122023101161980" data-react-helmet="true" property="fb:app_id"/><meta content="239522418693" data-react-helmet="true" property="fb:pages"/><meta content="l3rQIge7B2N_G1cQl0VZP0y7-nE" data-react-helmet="true" name="alexaVerifyID"/><meta charset="utf-8" data-react-helmet="true"/><meta content="width=device-width,initial-scale=1.0, maximum-scale=1.0, user-scalable=0" data-react-helmet="true" name="viewport"/><meta content="Book Hotels in Dubai at lowest Prices on Goibibo. Get Free Cancellation &amp; Instant Refund on 1863  Dubai Hotels starting from  ₹1163. Use code GOINTH to get discounts upto 30% off on Budget Hotels, Luxury Hotels &amp; Business Hotels in Dubai." data-react-helmet="true" name="description"/><meta content="Book Hotels in Dubai at lowest Prices on Goibibo. Get Free Cancellation &amp; Instant Refund on 1863  Dubai Hotels starting from  ₹1163. Use code GOINTH to get discounts upto 30% off on Budget Hotels, Luxury Hotels &amp; Business Hotels in Dubai." data-react-helmet="true" property="og:description"/><meta content="hotels in Dubai, best hotels in Dubai, Dubai hotels, Dubai hotel booking, Dubai hotel price, Dubai hotel deals, book Dubai hotels, goibibo Dubai hotels" data-react-helmet="true" name="keywords"/><meta content="Hotels in Dubai, 1863  Dubai Hotels from  ₹1163 + upto 30% off" data-react-helmet="true" property="og:title"/><meta content="https://www.goibibo.com/hotels-international/hotels-in-dubai-ct/" data-react-helmet="true" property="og:url"/><meta content="Mon Sep 05 2022 17:40:16 GMT+0530 (India Standard Time)" data-react-helmet="true" name="timestamp"/>
# <link data-react-helmet="true" href="/favicon.ico" rel="shortcut icon"/><link data-react-helmet="true" href="/manifest.json" rel="manifest"/><link data-react-helmet="true" href="//goibibo.ibcdn.com/" rel="preconnect"/><link data-react-helmet="true" href="//goibibo.ibcdn.com/" rel="dns-prefetch"/><link data-react-helmet="true" href="//hermes.goibibo.com/" rel="dns-prefetch"/><link data-react-helmet="true" href="//voyager.goibibo.com/" rel="dns-prefetch"/><link data-react-helmet="true" href="//googleads.g.doubleclick.net" rel="dns-prefetch"/><link data-react-helmet="true" href="//ugc.goibibo.com/" rel="dns-prefetch"/><link data-react-helmet="true" href="//www.googletagmanager.com" rel="dns-prefetch"/><link data-react-helmet="true" href="//www.google-analytics.com" rel="dns-prefetch"/><link data-react-helmet="true" href="https://goibibo.ibcdn.com/hotelsnew/static/images/go@2x.png" rel="icon" sizes="192x192"/><link data-react-helmet="true" href="/favicon.ico" rel="shortcut icon"/><link as="style" data-react-helmet="true" href="https://goibibo.ibcdn.com/styleguide/css/combinedStyles.css" media="all" rel="preload stylesheet" type="text/css"/><link as="style" data-react-helmet="true" href="https://jsak.goibibo.com/pwa_v3/happy-header/4.3.1/ssr/header.css" media="all" rel="preload stylesheet" type="text/css"/><link data-react-helmet="true" href="http://www.goibibo.com/images/favicon.ico" rel="shortcut icon" type="image/ico"/><link data-react-helmet="true" href="https://www.goibibo.com/hotels-international/hotels-in-dubai-ct/" rel="canonical"/><link data-react-helmet="true" href="android-app://com.goibibo/goibibo/www.goibibo.com/app/intl-hotels/hotels-in-dubai-ct/?params={'go_data': {'n': u'dubai', 'oid': '4248184514535583088', 't': 'area', 'cid': '4248184514535583088'}, 'tag_id': 202}" rel="alternate"/>
# <style>
#           @font-face {
#             font-family: 'Quicksand';
#             font-style: normal;
#             font-weight: 400;
#             font-display: swap;
#             src: url(https://fonts.gstatic.com/s/quicksand/v29/6xKtdSZaM9iE8KbpRA_hK1QNYuDyPw.woff2) format('woff2');
#             unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
#           }
#           @font-face {
#             font-family: 'Quicksand';
#             font-style: normal;
#             font-weight: 700;
#             font-display: swap;
#             src: url(https://fonts.gstatic.com/s/quicksand/v29/6xKtdSZaM9iE8KbpRA_hK1QNYuDyPw.woff2) format('woff2');
#             unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
#           }
#         </style>
# <style data-styled="true" data-styled-version="5.2.0">html{font-size:10px;}/*!sc*/
# html,.scroll-container{overflow-y:scroll;}/*!sc*/
# html.modal-open,html.lock-scroll{overflow:hidden;}/*!sc*/
# body.moda-open{overflow:inherit;}/*!sc*/
# @media (prefers-reduced-motion){html,.scroll-container{-webkit-scroll-behavior:auto;-moz-scroll-behavior:auto;-ms-scroll-behavior:auto;scroll-behavior:auto;}}/*!sc*/
# *{padding:0;margin:0;-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box;}/*!sc*/
# .headerBox{z-index:99;}/*!sc*/
# .oh{height:110vh;overflow-y:hidden;position:fixed;width:100%;margin:0px auto;}/*!sc*/
# body{background:#eef4fd;color:#141823;font:400 1.2rem/1.33 "Helvetica Neue",Helvetica,Arial,sans-serif;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;}/*!sc*/
# data-styled.g1[id="sc-global-hmTaKC1"]{content:"sc-global-hmTaKC1,"}/*!sc*/
# .iXNEUz{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background-color:#FFFFFF;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;position:relative;}/*!sc*/
# data-styled.g2[id="footer-seostyles__SeoOuterDiv-sc-1ycveqg-0"]{content:"iXNEUz,"}/*!sc*/
# .iSRlba{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding:1rem 3rem;width:100%;border-bottom:0.1rem solid rgb(225,231,238);-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# .hKOZtX{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding:1rem 3rem;border-bottom:0.1rem solid rgb(225,231,238);-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# data-styled.g3[id="footer-seostyles__BottomFooterWrapper-sc-1ycveqg-1"]{content:"iSRlba,hKOZtX,"}/*!sc*/
# .fgtjUn{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-self:flex-end;-ms-flex-item-align:end;align-self:flex-end;}/*!sc*/
# .ivnclR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-undefined;-ms-flex-undefined;undefined;}/*!sc*/
# data-styled.g4[id="footer-seostyles__DisplayFlex-sc-1ycveqg-2"]{content:"fgtjUn,ivnclR,"}/*!sc*/
# .fOIhbU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-undefined;-ms-flex-undefined;undefined;}/*!sc*/
# data-styled.g5[id="footer-seostyles__DisplayFlexColumn-sc-1ycveqg-3"]{content:"fOIhbU,"}/*!sc*/
# .enFwYa{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background-color:#FFFFFF;padding:3.5rem 3rem;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;border-bottom:0.1rem solid rgb(225,231,238);}/*!sc*/
# data-styled.g6[id="footer-seostyles__SeoFooterWrapper-sc-1ycveqg-4"]{content:"enFwYa,"}/*!sc*/
# .kmZcWw{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-flex:1;-ms-flex:1;flex:1;margin-right:0.5rem;}/*!sc*/
# data-styled.g7[id="footer-seostyles__ColumnDiv-sc-1ycveqg-5"]{content:"kmZcWw,"}/*!sc*/
# .isbBTD{font-size:1.2rem;margin-bottom:1.5rem;font-family:Quicksand;font-weight:bold;width:86%;height:3rem;text-transform:uppercase;}/*!sc*/
# data-styled.g8[id="footer-seostyles__HeaderPara-sc-1ycveqg-6"]{content:"isbBTD,"}/*!sc*/
# .fQeGZn{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# .fQeGZn li{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;padding-bottom:0.5rem;}/*!sc*/
# data-styled.g9[id="footer-seostyles__ContentWrapper-sc-1ycveqg-7"]{content:"fQeGZn,"}/*!sc*/
# .lkAtYI{color:#2274E0;font-weight:bold;-webkit-text-decoration:none;text-decoration:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g10[id="footer-seostyles__PrimaryLink-sc-1ycveqg-8"]{content:"lkAtYI,"}/*!sc*/
# .hcFFRg{color:#666666;font-size:1.1rem;}/*!sc*/
# .hcFFRg:hover{color:#FF6D38;}/*!sc*/
# data-styled.g11[id="footer-seostyles__LinkWrapper-sc-1ycveqg-9"]{content:"hcFFRg,"}/*!sc*/
# .gXZWhY{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}/*!sc*/
# data-styled.g21[id="Layouts__Row-sc-1yzlivq-1"]{content:"gXZWhY,"}/*!sc*/
# .cepiji{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# data-styled.g22[id="Layouts__Column-sc-1yzlivq-3"]{content:"cepiji,"}/*!sc*/
# .cTbeCN{background-color:#E8F3FF;width:100%;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# data-styled.g27[id="DetailsPageLayoutstyles__WrapperSection-sc-t8l2sc-0"]{content:"cTbeCN,"}/*!sc*/
# .dSytVh{max-width:120rem;width:100%;padding-top:1.5rem;margin:0 auto;}/*!sc*/
# data-styled.g28[id="DetailsPageLayoutstyles__WrapperDiv-sc-t8l2sc-1"]{content:"dSytVh,"}/*!sc*/
# .kMvPWx{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;padding:2.5rem;width:100%;}/*!sc*/
# data-styled.g29[id="ContentContainerstyles__MainContentWrapperStyle-sc-jinyls-0"]{content:"kMvPWx,"}/*!sc*/
# .dvBEUl{font-size:1.6rem;line-height:1.4;overflow:hidden;height:undefinedpx;}/*!sc*/
# data-styled.g31[id="ContentContainerstyles__ContentWrapper-sc-jinyls-2"]{content:"dvBEUl,"}/*!sc*/
# .eykMFV{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;border-bottom:0.1rem solid #C2C2C2;padding:2rem 2.5rem;}/*!sc*/
# data-styled.g32[id="AboutPropertiesstyles__HeadingTextWrapperStyle-sc-4xqpe7-1"]{content:"eykMFV,"}/*!sc*/
# .knLjJo{font-size:1.6rem;line-height:1.4;background:white;border-radius:1.2000000000000002rem;}/*!sc*/
# .knLjJo >p{height:100%;}/*!sc*/
# data-styled.g33[id="AboutPropertiesstyles__MainContentTextStyle-sc-4xqpe7-2"]{content:"knLjJo,"}/*!sc*/
# .cVKOQr{font-size:2.2rem;font-family:Quicksand;font-weight:bold;}/*!sc*/
# data-styled.g34[id="AboutPropertiesstyles__HeadingTextStyle-sc-4xqpe7-3"]{content:"cVKOQr,"}/*!sc*/
# .eHRHNU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# data-styled.g35[id="dwebCommonstyles__CenteredSpaceWrap-sc-112ty3f-0"]{content:"eHRHNU,"}/*!sc*/
# .ibYPGm{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# data-styled.g36[id="dwebCommonstyles__CenteredDivWrap-sc-112ty3f-1"]{content:"ibYPGm,"}/*!sc*/
# .fVGWFo{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:100%;}/*!sc*/
# data-styled.g37[id="dwebCommonstyles__BaseColumnWrap-sc-112ty3f-2"]{content:"fVGWFo,"}/*!sc*/
# .erTvHU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g39[id="dwebCommonstyles__FlexItem-sc-112ty3f-4"]{content:"erTvHU,"}/*!sc*/
# .bWxfZG{color:#2274E0;}/*!sc*/
# data-styled.g45[id="dwebCommonstyles__PrimaryLink-sc-112ty3f-10"]{content:"bWxfZG,"}/*!sc*/
# .QWIoF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;cursor:pointer;border:none;background-color:#FF6D38;color:#FFFFFF;font-family:Quicksand;font-weight:bold;text-transform:uppercase;border-radius:1.2000000000000002rem;font-size:1.6rem;}/*!sc*/
# .QWIoF:focus{box-shadow:none;outline-offset:0;outline:0;}/*!sc*/
# data-styled.g47[id="dwebCommonstyles__ButtonBase-sc-112ty3f-12"]{content:"QWIoF,"}/*!sc*/
# .SbaeP{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;position:-webkit-sticky;position:sticky;top:-.01rem;z-index:9;background-color:#2274E0;}/*!sc*/
# data-styled.g60[id="SearchWidgetUIstyles__OuterWrapDiv-sc-1pb2jm7-0"]{content:"SbaeP,"}/*!sc*/
# .bPjPlU{max-width:120rem;width:100%;margin:0 auto;padding:1.2000000000000002rem 0;background-color:#2274E0;}/*!sc*/
# data-styled.g61[id="SearchWidgetUIstyles__WrapperStyle-sc-1pb2jm7-1"]{content:"bPjPlU,"}/*!sc*/
# .cUZYGS{width:33.7rem;padding-right:1.2000000000000002rem;position:relative;}/*!sc*/
# data-styled.g62[id="SearchWidgetUIstyles__SearchWrapperArea-sc-1pb2jm7-2"]{content:"cUZYGS,"}/*!sc*/
# .bbLdVI{padding-right:1.2000000000000002rem;width:16.5rem;}/*!sc*/
# data-styled.g63[id="SearchWidgetUIstyles__CheckinCheckoutWrapper-sc-1pb2jm7-3"]{content:"bbLdVI,"}/*!sc*/
# .kRnkxX{padding-right:0.5rem;position:relative;width:25.4rem;}/*!sc*/
# data-styled.g64[id="SearchWidgetUIstyles__PaxWrapperStyle-sc-1pb2jm7-4"]{content:"kRnkxX,"}/*!sc*/
# .bJzRCa{color:white;padding-bottom:0.5rem;padding-left:0.2rem;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g65[id="SearchWidgetUIstyles__SearchLabelStyle-sc-1pb2jm7-5"]{content:"bJzRCa,"}/*!sc*/
# .hqCaBO{background-color:#1958B6;color:white;border:none;font-size:1.6rem;font-family:Quicksand;font-weight:bold;display:block;width:100%;height:4.2rem;padding:1rem 1rem 1.2000000000000002rem 1rem;line-height:1.3;border-radius:0.8rem;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-packjustify-conent:center;-webkit-justify-conent:center;-ms-flex-packjustify-conent:center;justify-conent:center;}/*!sc*/
# .hqCaBO::-webkit-input-placeholder{color:white;opacity:0.5;.SearchWidgetUIstyles__SearchInputStyle-sc-1pb2jm7-6.font-size;.SearchWidgetUIstyles__SearchInputStyle-sc-1pb2jm7-6.font-family;.SearchWidgetUIstyles__SearchInputStyle-sc-1pb2jm7-6.font-weight;}/*!sc*/
# .hqCaBO:focus{box-shadow:none;outline:none;color:transparent;text-shadow:0px 0px 0px white;}/*!sc*/
# data-styled.g66[id="SearchWidgetUIstyles__SearchInputStyle-sc-1pb2jm7-6"]{content:"hqCaBO,"}/*!sc*/
# .klwECc{background-color:#FFFFFF;margin-top:1.5rem;height:4.2rem;width:19.6rem;color:#141823;}/*!sc*/
# data-styled.g67[id="SearchWidgetUIstyles__UpdateSearchBtn-sc-1pb2jm7-7"]{content:"klwECc,"}/*!sc*/
# .cTOBSY{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;position:relative;}/*!sc*/
# data-styled.g68[id="SearchWidgetAutosuggeststyles__AutocompleteWrapperStyles-sc-agkhrg-0"]{content:"cTOBSY,"}/*!sc*/
# .gKcOjH{background-color:#1958B6;color:white;border:none;font-size:1.6rem;font-family:Quicksand;font-weight:bold;text-transform:capitalize;display:block;width:100%;height:4.2rem;padding:1rem 1rem 1.2000000000000002rem 1rem;line-height:1.3;border-radius:0.8rem;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-packjustify-conent:center;-webkit-justify-conent:center;-ms-flex-packjustify-conent:center;justify-conent:center;}/*!sc*/
# .gKcOjH::-webkit-input-placeholder{color:white;opacity:0.5;.SearchWidgetAutosuggeststyles__SearchInputStyles-sc-agkhrg-1.font-size;.SearchWidgetAutosuggeststyles__SearchInputStyles-sc-agkhrg-1.font-family;.SearchWidgetAutosuggeststyles__SearchInputStyles-sc-agkhrg-1.font-weight;}/*!sc*/
# .gKcOjH:focus{box-shadow:none;outline:none;}/*!sc*/
# data-styled.g69[id="SearchWidgetAutosuggeststyles__SearchInputStyles-sc-agkhrg-1"]{content:"gKcOjH,"}/*!sc*/
# .escWIO{color:#FFFFFF;padding-bottom:0.5rem;padding-left:0.2rem;}/*!sc*/
# data-styled.g70[id="SearchWidgetAutosuggeststyles__SearchLabelStyles-sc-agkhrg-2"]{content:"escWIO,"}/*!sc*/
# .cWfejb{width:1.5rem;height:1.5rem;fill:black;cursor:pointer;}/*!sc*/
# .eEEGes{width:1.5rem;height:1.5rem;fill:#e47544;cursor:pointer;}/*!sc*/
# data-styled.g72[id="RupeeIcon-sc-5hlwf0-1"]{content:"cWfejb,eEEGes,"}/*!sc*/
# .cqbqIm{z-index:99;position:absolute;top:6rem;left:0;list-style-type:none;background:#FFFFFF;border-radius:4px;box-shadow:0 2px 14px 0 rgba(0,0,0,0.16);-webkit-transform:translateY(4px);-ms-transform:translateY(4px);transform:translateY(4px);min-width:54rem;max-height:90vh;overflow-y:auto;}/*!sc*/
# .cqbqIm .HomePageAutosuggeststyles__SearchListItem-sc-1v6s32j-2 :first-of-type{border-top:none;}/*!sc*/
# .cqbqIm::-webkit-scrollbar{-webkit-appearance:none;width:7px;}/*!sc*/
# .cqbqIm::-webkit-scrollbar-thumb{border-radius:4px;background-color:#777777;box-shadow:0 0 1px #C2C2C2;}/*!sc*/
# data-styled.g84[id="HomePageAutosuggeststyles__SearchMenuStyles-sc-1v6s32j-3"]{content:"cqbqIm,"}/*!sc*/
# .izIqO{width:2.2rem;height:2.2rem;fill:#647A97;cursor:pointer;}/*!sc*/
# data-styled.g109[id="HappyHotelSearchIcon-sc-1k3e01m-1"]{content:"izIqO,"}/*!sc*/
# .iRjLHx{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g253[id="TARatingstyles__TARatingWrapper-sc-1s1v6m6-1"]{content:"iRjLHx,"}/*!sc*/
# .kQGPQI{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;width:12px;height:12px;border-radius:50%;overflow:hidden;position:relative;border:1px solid #00AA6C;margin-right:1px;}/*!sc*/
# .kQGPQI:after{position:absolute;content:'';background:#00AA6C;display:block;width:12px;height:12px;top:0;left:0;}/*!sc*/
# .kQGPQI.half::after{left:-6px;}/*!sc*/
# .kQGPQI.blank:after{background:#FFFFFF;}/*!sc*/
# .boyduz{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;width:10px;height:10px;border-radius:50%;overflow:hidden;position:relative;border:1px solid #00AA6C;margin-right:1px;}/*!sc*/
# .boyduz:after{position:absolute;content:'';background:#00AA6C;display:block;width:10px;height:10px;top:0;left:0;}/*!sc*/
# .boyduz.half::after{left:-5px;}/*!sc*/
# .boyduz.blank:after{background:#FFFFFF;}/*!sc*/
# data-styled.g254[id="TARatingstyles__TARatingListItem-sc-1s1v6m6-3"]{content:"kQGPQI,boyduz,"}/*!sc*/
# .cOCoHb{width:2.6rem;height:2rem;fill:black;margin:0 4px 0 0;}/*!sc*/
# .isSgDd{width:1.8rem;height:1.2rem;fill:black;margin:0 4px 0 0;}/*!sc*/
# data-styled.g255[id="HappyTripAdvisorIcon-sc-na8tet-1"]{content:"cOCoHb,isSgDd,"}/*!sc*/
# .kKbDnT{cursor:pointer;}/*!sc*/
# data-styled.g285[id="RatingStarIcon-sc-1lv0lb2-1"]{content:"kKbDnT,"}/*!sc*/
# .fkLhZV{width:2rem;height:2rem;fill:#777777;cursor:pointer;}/*!sc*/
# data-styled.g488[id="ActivitiesIcon-sc-ffc2ds-1"]{content:"fkLhZV,"}/*!sc*/
# .dhAwV{width:1.5rem;height:1,5rem;fill:#777777;cursor:pointer;}/*!sc*/
# data-styled.g489[id="AirportTransportIcon-sc-bnhbgr-1"]{content:"dhAwV,"}/*!sc*/
# .cKkNjV{width:1.5rem;height:1.5rem;fill:#777777;cursor:pointer;}/*!sc*/
# data-styled.g490[id="BanquetHallIcon-sc-5ff6c4-1"]{content:"cKkNjV,"}/*!sc*/
# .hEWzfH{width:1.5rem;height:1.5rem;fill:#777777;cursor:pointer;}/*!sc*/
# data-styled.g495[id="ConferenceRoomIcon-sc-n8vzmu-1"]{content:"hEWzfH,"}/*!sc*/
# .idnRjx{width:1.5rem;height:1.5rem;fill:#777777;cursor:pointer;}/*!sc*/
# data-styled.g502[id="HouseKeepingIcon-sc-5ioupd-1"]{content:"idnRjx,"}/*!sc*/
# .gRbrwc{width:1.5rem;height:1.5rem;fill:#777777;cursor:pointer;}/*!sc*/
# data-styled.g507[id="ParkingIcon-sc-8rt39-1"]{content:"gRbrwc,"}/*!sc*/
# .coyBLE{width:1.5rem;height:1.5rem;fill:#777777;cursor:pointer;}/*!sc*/
# data-styled.g510[id="RestaurantIcon-sc-1f8rkpo-1"]{content:"coyBLE,"}/*!sc*/
# .iCMKmP{width:1.2rem;height:1.2rem;fill:#2274E0;cursor:pointer;}/*!sc*/
# .gbFfwh{width:1.2rem;height:1.2rem;fill:#777777;cursor:pointer;}/*!sc*/
# data-styled.g516[id="SwimmingIcon-sc-2o20qz-1"]{content:"iCMKmP,gbFfwh,"}/*!sc*/
# .ksUoVx{width:1.5rem;height:1.5rem;margin:0;}/*!sc*/
# .ksUoVx g path:last-child{fill:#777777;}/*!sc*/
# data-styled.g522[id="RoundedCheckbox-sc-4skzta-1"]{content:"ksUoVx,"}/*!sc*/
# .DyrDV{width:1.5rem;height:1.5rem;fill:#647A97;}/*!sc*/
# data-styled.g523[id="HappyWifiIcon-sc-9vspjr-1"]{content:"DyrDV,"}/*!sc*/
# .kUbNqz{font-size:1rem;}/*!sc*/
# data-styled.g588[id="PersuasionHoverTextstyles__PersuasionHoverTitleSpan-sc-1c06rw1-1"]{content:"eesUpw,kUbNqz,"}/*!sc*/
# .fLXzko{width:22rem;top:1.5rem;left:0;max-width:30rem;padding:1rem 0;z-index:3;visibility:hidden;-webkit-transition:opacity 0.8s;transition:opacity 0.8s;position:absolute;}/*!sc*/
# .dEJHxg{width:22rem;bottom:1.5rem;left:0;max-width:30rem;padding:1rem 0;z-index:3;visibility:hidden;-webkit-transition:opacity 0.8s;transition:opacity 0.8s;position:absolute;}/*!sc*/
# .eRMKRj{width:22rem;top:2rem;right:0;max-width:30rem;padding:1rem 0;z-index:3;visibility:hidden;-webkit-transition:opacity 0.8s;transition:opacity 0.8s;position:absolute;}/*!sc*/
# .hzlAHj{width:22rem;top:2rem;right:0;bottom:2rem;right:0;max-width:30rem;padding:1rem 0;z-index:3;visibility:hidden;-webkit-transition:opacity 0.8s;transition:opacity 0.8s;position:absolute;}/*!sc*/
# data-styled.g589[id="PersuasionHoverTextstyles__HiddenDropdownWrapperDiv-sc-1c06rw1-3"]{content:"fLXzko,dEJHxg,eRMKRj,hzlAHj,"}/*!sc*/
# .dZACqb{position:relative;text-align:left;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;margin-right:0.8rem;}/*!sc*/
# .dZACqb:hover > .PersuasionHoverTextstyles__HiddenDropdownWrapperDiv-sc-1c06rw1-3{visibility:visible;}/*!sc*/
# .exclTC{position:relative;text-align:left;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;margin-right:0.8rem;margin-top:0.5rem;}/*!sc*/
# .exclTC:hover > .PersuasionHoverTextstyles__HiddenDropdownWrapperDiv-sc-1c06rw1-3{visibility:visible;}/*!sc*/
# .gVdEEf{position:relative;text-align:left;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;}/*!sc*/
# .gVdEEf:hover > .PersuasionHoverTextstyles__HiddenDropdownWrapperDiv-sc-1c06rw1-3{visibility:visible;}/*!sc*/
# data-styled.g590[id="PersuasionHoverTextstyles__HoverTargetWrapperDiv-sc-1c06rw1-4"]{content:"dZACqb,exclTC,gVdEEf,"}/*!sc*/
# .jsvtkA{background-color:#FFFFFF;border-radius:0.4rem;box-shadow:0 0.1rem 0.4rem rgba(0,0,0,0.25);}/*!sc*/
# data-styled.g591[id="PersuasionHoverTextstyles__TopDiv-sc-1c06rw1-5"]{content:"jsvtkA,"}/*!sc*/
# .VnDcg{position:absolute;margin-left:-1rem;width:2.4rem;height:1.2rem;overflow:hidden;}/*!sc*/
# .VnDcg::after{content:'';position:absolute;width:1.3rem;height:1.2rem;left:50%;}/*!sc*/
# data-styled.g592[id="PersuasionHoverTextstyles__TipUI-sc-1c06rw1-7"]{content:"VnDcg,"}/*!sc*/
# .cTwnQr{top:-0.2rem;left:10%;}/*!sc*/
# .cTwnQr::after{-webkit-transform:translate(-50%,50%) rotate(45deg);-ms-transform:translate(-50%,50%) rotate(45deg);transform:translate(-50%,50%) rotate(45deg);background:#D1E5FF;box-shadow:0 0.1rem 0.4rem rgba(0,0,0,0.25);}/*!sc*/
# .emRqvH{bottom:-0.2rem;left:15%;}/*!sc*/
# .emRqvH::after{-webkit-transform:translate(-50%,-50%) rotate(45deg);-ms-transform:translate(-50%,-50%) rotate(45deg);transform:translate(-50%,-50%) rotate(45deg);background:#d1e5ff;box-shadow:0 0.1rem 0.4rem rgba(0,0,0,0.25);}/*!sc*/
# .btpTpE{top:-0.2rem;right:15%;}/*!sc*/
# .btpTpE::after{-webkit-transform:translate(-50%,50%) rotate(45deg);-ms-transform:translate(-50%,50%) rotate(45deg);transform:translate(-50%,50%) rotate(45deg);background:#e9f6ea;box-shadow:0 0.1rem 0.4rem rgba(0,0,0,0.25);}/*!sc*/
# .ckNata{top:-0.2rem;right:15%;bottom:-0.2rem;right:15%;}/*!sc*/
# .ckNata::after{-webkit-transform:translate(-50%,50%) rotate(45deg);-ms-transform:translate(-50%,50%) rotate(45deg);transform:translate(-50%,50%) rotate(45deg);-webkit-transform:translate(-50%,50%) rotate(45deg);-ms-transform:translate(-50%,50%) rotate(45deg);transform:translate(-50%,50%) rotate(45deg);background:#fef8e5;box-shadow:0 0.1rem 0.4rem rgba(0,0,0,0.25);}/*!sc*/
# .ffZvHe{bottom:-0.2rem;left:15%;}/*!sc*/
# .ffZvHe::after{-webkit-transform:translate(-50%,-50%) rotate(45deg);-ms-transform:translate(-50%,-50%) rotate(45deg);transform:translate(-50%,-50%) rotate(45deg);background:#e9f6ea;box-shadow:0 0.1rem 0.4rem rgba(0,0,0,0.25);}/*!sc*/
# data-styled.g594[id="PersuasionHoverTextstyles__TipPositioning-sc-1c06rw1-10"]{content:"cTwnQr,emRqvH,btpTpE,ckNata,ffZvHe,"}/*!sc*/
# .bKybni{padding:1rem;background-color:#D1E5FF;}/*!sc*/
# .eMICSc{padding:1rem;color:#141823;background-color:#d1e5ff;}/*!sc*/
# .jBFTJt{padding:1rem;color:#141823;background-color:#e9f6ea;}/*!sc*/
# .jiSPjw{padding:1rem;color:#141823;background-color:#fef8e5;}/*!sc*/
# data-styled.g595[id="PersuasionHoverTextstyles__TextBlockDropDownWrapper-sc-1c06rw1-13"]{content:"bKybni,eMICSc,jBFTJt,jiSPjw,"}/*!sc*/
# .dKhclC{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-self:flex-start;-ms-flex-item-align:start;align-self:flex-start;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0.30000000000000004rem 1rem 0.30000000000000004rem 0.5rem;margin-bottom:0.5rem;background:#FFFFFF;color:#1958b6;border-radius:2.5rem;}/*!sc*/
# .iiqiJI{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-self:flex-start;-ms-flex-item-align:start;align-self:flex-start;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0.30000000000000004rem 1rem 0.30000000000000004rem 0.5rem;margin-bottom:0.5rem;background:#ffffff;color:#2276e3;border-radius:2.5rem;}/*!sc*/
# .dlYPNc{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-self:flex-start;-ms-flex-item-align:start;align-self:flex-start;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0.30000000000000004rem 1rem 0.30000000000000004rem 0.5rem;margin-bottom:0.5rem;background:#ffffff;color:#2bac36;border-radius:2.5rem;}/*!sc*/
# .eTVzot{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-self:flex-start;-ms-flex-item-align:start;align-self:flex-start;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0.30000000000000004rem 1rem 0.30000000000000004rem 0.5rem;margin-bottom:0.5rem;background:#ffffff;color:#de7d00;border-radius:2.5rem;}/*!sc*/
# data-styled.g597[id="PersuasionHoverTextstyles__TextBlockDDHeading-sc-1c06rw1-16"]{content:"dKhclC,iiqiJI,dlYPNc,eTVzot,"}/*!sc*/
# .dOXonG{color:#1958b6;background-color:#FFFFFF;padding:0 0 0 0.5rem;text-transform:capitalize;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .bKIDQm{color:#2276e3;background-color:#ffffff;padding:0 0 0 0.5rem;text-transform:capitalize;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .cDMwcC{color:#2bac36;background-color:#ffffff;padding:0 0 0 0.5rem;text-transform:capitalize;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .bKeEXq{color:#de7d00;background-color:#ffffff;padding:0 0 0 0.5rem;text-transform:capitalize;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g598[id="PersuasionHoverTextstyles__TextBlockDDHeadingSpan-sc-1c06rw1-18"]{content:"dOXonG,bKIDQm,cDMwcC,bKeEXq,"}/*!sc*/
# .hTeJTo{line-height:1.3;font-size:1.4000000000000001rem;padding-top:1rem;}/*!sc*/
# data-styled.g599[id="PersuasionHoverTextstyles__TextBlockDDFilterText-sc-1c06rw1-20"]{content:"hTeJTo,"}/*!sc*/
# .hnCBjZ{margin-top:1rem;color:#2274E0;cursor:pointer;}/*!sc*/
# data-styled.g600[id="PersuasionHoverTextstyles__BlueLinkText-sc-1c06rw1-22"]{content:"hnCBjZ,"}/*!sc*/
# .iBVDvl{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g601[id="PersuasionHoverTextstyles__WrapperDiv-sc-1c06rw1-24"]{content:"iBVDvl,"}/*!sc*/
# .jbrgJv{border-radius:1.5rem;cursor:pointer;color:#1958b6;background-color:#FFFFFF;text-transform:capitalize;padding:0.3rem 0.8rem 0.3rem 0.8rem;border:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .jbrgJv span{max-width:30rem;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}/*!sc*/
# .fPQyOd{border-radius:1.5rem;cursor:pointer;color:#2276e3;background-color:#eef4fd;text-transform:capitalize;padding:0.3rem 0.8rem 0.3rem 0.8rem;border:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .fPQyOd span{max-width:16rem;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}/*!sc*/
# .hdeFeN{border-radius:1.5rem;cursor:pointer;color:#2276e3;background-color:#eef4fd;text-transform:capitalize;padding:0.3rem 0.8rem 0.3rem 0.8rem;border:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .hdeFeN span{max-width:30rem;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}/*!sc*/
# .kITzfl{border-radius:1.5rem;cursor:pointer;color:#2bac36;background-color:#e9f6ea;text-transform:capitalize;padding:0.3rem 0.8rem 0.3rem 0.8rem;border:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .kITzfl span{max-width:30rem;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}/*!sc*/
# .kiwLmP{border-radius:1.5rem;cursor:pointer;color:#de7d00;background-color:#fef8e5;text-transform:capitalize;padding:0.3rem 0rem 0.3rem 0.8rem;border:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .kiwLmP span{max-width:30rem;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}/*!sc*/
# .gZbVNB{border-radius:1.5rem;cursor:pointer;color:#2bac36;background-color:#ffffff;text-transform:capitalize;padding:0.3rem 0 0.3rem 0;border:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .gZbVNB span{max-width:30rem;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}/*!sc*/
# .kGZtrT{border-radius:1.5rem;color:#4f525a;background-color:#ffffff;text-transform:capitalize;padding:0.3rem 0 0.3rem 0;border:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .kGZtrT span{max-width:30rem;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}/*!sc*/
# data-styled.g602[id="PersuasionHoverTextstyles__TextWrapperSpan-sc-1c06rw1-26"]{content:"jbrgJv,fPQyOd,hdeFeN,kITzfl,kiwLmP,gZbVNB,kGZtrT,"}/*!sc*/
# .SFoM{margin-right:0.5rem;}/*!sc*/
# data-styled.g605[id="PersuasionHoverTextstyles__MiniIconWrapperSpan-sc-1c06rw1-31"]{content:"SFoM,"}/*!sc*/
# .dOaGza{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-right:0.8rem;}/*!sc*/
# .deiipT{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-right:0.5rem;}/*!sc*/
# data-styled.g606[id="PersuasionHoverTextstyles__MainTextIconWrapperSpan-sc-1c06rw1-33"]{content:"dOaGza,deiipT,"}/*!sc*/
# .kPTrPZ{width:1.2rem;height:1.2rem;fill:#2bac36;cursor:pointer;}/*!sc*/
# .htuWFx{height:3.2rem;fill:#2274E0;cursor:pointer;}/*!sc*/
# data-styled.g619[id="GiftTagIcon-sc-1f8umx7-1"]{content:"kPTrPZ,htuWFx,"}/*!sc*/
# .htSowo{width:1.2rem;height:1.2rem;fill:#de7d00;cursor:pointer;}/*!sc*/
# data-styled.g621[id="OfferIcon-sc-hzz5jm-1"]{content:"htSowo,"}/*!sc*/
# .cvmhSL{width:1.6rem;height:1.6rem;cursor:pointer;}/*!sc*/
# .cvmhSL g path:last-child{fill:#2276e3;}/*!sc*/
# .gDdQLV{width:1.6rem;height:1.6rem;cursor:pointer;}/*!sc*/
# .gDdQLV g path:last-child{fill:#4f525a;}/*!sc*/
# data-styled.g623[id="UgcPersuasionIcon-sc-xk3nsn-1"]{content:"cvmhSL,gDdQLV,"}/*!sc*/
# .gXQhmM{width:1.6rem;height:1.6rem;fill:#2bac36;cursor:pointer;}/*!sc*/
# .gXQhmM g path:last-child{fill:#2bac36;}/*!sc*/
# data-styled.g626[id="FreeBreakfast__FreeBreakfastIcon-sc-5mryup-1"]{content:"gXQhmM,"}/*!sc*/
# .cHCDgP{width:1.2rem;height:1.2rem;margin:0 0.5rem 0 0;fill:#FFFFFF;}/*!sc*/
# data-styled.g1080[id="HappyTimerIcon__HappyTimerClockIcon-sc-1olnuf0-1"]{content:"cHCDgP,"}/*!sc*/
# .ga-dlWY{color:fff;}/*!sc*/
# data-styled.g1081[id="Countdowntimerstyles__DealText-sc-qm7a50-0"]{content:"ga-dlWY,"}/*!sc*/
# .jYONsZ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-top:1rem;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;border:1px solid #FBE5DB;border-radius:0.8rem;padding:0.8rem;margin:1rem 0;background-color:#FBE5DB;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;padding-bottom:0px;margin-bottom:0;padding-top:7px;margin-top:0px;}/*!sc*/
# data-styled.g1082[id="noworneverdealtimerstyles__NoworNeverPersuationWrapper-sc-3mmrf0-0"]{content:"jYONsZ,"}/*!sc*/
# .gmIecb{color:#FFFFFF;font-weight:bold;}/*!sc*/
# .iOmsnw{color:#e47544;font-weight:bold;}/*!sc*/
# data-styled.g1083[id="noworneverdealtimerstyles__DealText-sc-3mmrf0-1"]{content:"gmIecb,iOmsnw,"}/*!sc*/
# .eKycmB{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:-webkit-fit-content;width:-moz-fit-content;width:fit-content;background:#e47544;border-radius:10px;padding:0.30000000000000004rem 0.6000000000000001rem;margin-bottom:3px;}/*!sc*/
# .lgvEiR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:-webkit-fit-content;width:-moz-fit-content;width:fit-content;border-radius:10px;padding:0.30000000000000004rem 0.30000000000000004rem;margin-bottom:3px;}/*!sc*/
# data-styled.g1084[id="noworneverdealtimerstyles__DealPara-sc-3mmrf0-3"]{content:"eKycmB,lgvEiR,"}/*!sc*/
# .bVQlWC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g1087[id="noworneverdealtimerstyles__FlexContainerWrap-sc-3mmrf0-9"]{content:"bVQlWC,"}/*!sc*/
# .cCuURJ{margin-top:1rem;}/*!sc*/
# data-styled.g1165[id="SeoFiltersCardstyles__GoSafeCardBlockWrapper-sc-1wpwk3v-0"]{content:"cCuURJ,"}/*!sc*/
# .eZcncY{background-color:#FFFFFF;width:100%;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;padding:1rem;border-radius:1rem;}/*!sc*/
# data-styled.g1166[id="SeoFiltersCardstyles__SeoSrpContainerDiv-sc-1wpwk3v-1"]{content:"eZcncY,"}/*!sc*/
# .hJwnhR{width:100%;padding-bottom:2rem;font-size:1.8rem;font-family:Quicksand;font-weight:bold;}/*!sc*/
# data-styled.g1167[id="SeoFiltersCardstyles__SeoSrpHeaderPara-sc-1wpwk3v-2"]{content:"hJwnhR,"}/*!sc*/
# .fyvhoI{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}/*!sc*/
# .fyvhoI li{list-style-type:none;width:25%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;padding-right:3rem;padding-bottom:2rem;}/*!sc*/
# data-styled.g1168[id="SeoFiltersCardstyles__SeoSrpContentDiv-sc-1wpwk3v-3"]{content:"fyvhoI,"}/*!sc*/
# .heYBwQ{-webkit-text-decoration:none;text-decoration:none;color:#2274E0;font-size:1.4000000000000001rem;}/*!sc*/
# data-styled.g1169[id="SeoFiltersCardstyles__CityLink-sc-1wpwk3v-5"]{content:"heYBwQ,"}/*!sc*/
# .gKKQKF{-webkit-text-decoration:none;text-decoration:none;color:#141823;font-size:1.4000000000000001rem;}/*!sc*/
# data-styled.g1170[id="SeoFiltersCardstyles__CityNumberSpan-sc-1wpwk3v-6"]{content:"gKKQKF,"}/*!sc*/
# .bqTtTh{display:block;-webkit-text-decoration:none;text-decoration:none;color:#2274E0;font-size:1.4000000000000001rem;font-weight:bold;padding-bottom:1.5rem;text-align:right;padding-right:3rem;}/*!sc*/
# data-styled.g1171[id="SeoFiltersCardstyles__ShowAllLink-sc-1wpwk3v-7"]{content:"bqTtTh,"}/*!sc*/
# .cyDGnz{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;visibility:hidden;width:28rem;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;position:absolute;top:2.8rem;opacity:1;right:-15rem;padding:1rem;z-index:5;background-color:#FFFFFF;border-radius:0.4rem;box-shadow:0 0.1rem 0.4rem rgba(0,0,0,0.25);}/*!sc*/
# data-styled.g1172[id="ReviewAndRatingsstyles__GuestReviewPopUpWrap-sc-1nxmeoo-0"]{content:"cyDGnz,"}/*!sc*/
# .ixtzNN{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .ixtzNN:hover > .ReviewAndRatingsstyles__GuestReviewPopUpWrap-sc-1nxmeoo-0{visibility:visible;}/*!sc*/
# data-styled.g1173[id="ReviewAndRatingsstyles__HotelTotalReviewWrapper-sc-1nxmeoo-1"]{content:"ixtzNN,"}/*!sc*/
# .jZMken{position:relative;false width:22.4rem;}/*!sc*/
# .gwqHKN{position:relative;false:false;}/*!sc*/
# data-styled.g1174[id="ReviewAndRatingsstyles__ReviewAndRatingOuterContainer-sc-1nxmeoo-2"]{content:"jZMken,gwqHKN,"}/*!sc*/
# .eSCTHl{color:#777777;padding-right:0.5rem;border-right:0.1rem solid #EFF3F8;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;margin-left:0.8rem;}/*!sc*/
# .jjZSih{color:#777777;padding-right:0.5rem;border-right:0.1rem solid #EFF3F8;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;false;}/*!sc*/
# data-styled.g1176[id="ReviewAndRatingsstyles__TotalReviewCountText-sc-1nxmeoo-5"]{content:"eSCTHl,jjZSih,"}/*!sc*/
# .dVwjag{margin-right:0.5rem;padding:0.2rem 0.5rem;border-radius:0.2rem;background-color:#005d2f;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;max-width:6.5rem;}/*!sc*/
# .eOohTl{margin-right:0.5rem;padding:0.2rem 0.5rem;border-radius:0.2rem;background-color:#039556;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;max-width:6.5rem;}/*!sc*/
# .ctwqSG{margin-right:0.5rem;padding:0.2rem 0.5rem;border-radius:0.2rem;background-color:#5fa735;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;max-width:6.5rem;}/*!sc*/
# data-styled.g1177[id="ReviewAndRatingsstyles__AverageReviewWrapper-sc-1nxmeoo-7"]{content:"dVwjag,eOohTl,ctwqSG,"}/*!sc*/
# .ha-Djpg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;content:'';border-left:0.8rem solid transparent;position:absolute;left:-0.7rem;top:0rem;border-bottom-left-radius:0.3rem;-webkit-transform:rotate(44deg);-ms-transform:rotate(44deg);transform:rotate(44deg);border-bottom:0.8rem solid #005d2f;left:-0.4rem;top:-0.4rem;}/*!sc*/
# .hiqkHx{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;content:'';border-left:0.8rem solid transparent;position:absolute;left:-0.7rem;top:0rem;border-bottom-left-radius:0.3rem;-webkit-transform:rotate(44deg);-ms-transform:rotate(44deg);transform:rotate(44deg);border-bottom:0.8rem solid #039556;left:-0.4rem;top:-0.4rem;}/*!sc*/
# .bnqyMS{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;content:'';border-left:0.8rem solid transparent;position:absolute;left:-0.7rem;top:0rem;border-bottom-left-radius:0.3rem;-webkit-transform:rotate(44deg);-ms-transform:rotate(44deg);transform:rotate(44deg);border-bottom:0.8rem solid #5fa735;left:-0.4rem;top:-0.4rem;}/*!sc*/
# data-styled.g1178[id="ReviewAndRatingsstyles__ReviewTestStyles-sc-1nxmeoo-8"]{content:"ha-Djpg,hiqkHx,bnqyMS,"}/*!sc*/
# .fIKiFm{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g1179[id="ReviewAndRatingsstyles__TotalReviewOuterDiv-sc-1nxmeoo-9"]{content:"fIKiFm,"}/*!sc*/
# .ZTpPO{font-weight:bold;color:#FFFFFF;text-align:center;}/*!sc*/
# data-styled.g1180[id="ReviewAndRatingsstyles__AverageReviewText-sc-1nxmeoo-10"]{content:"ZTpPO,"}/*!sc*/
# .rWAoH{background-color:#00AA6C;color:#FFFFFF;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:13.2rem;height:10.6rem;border-radius:0.6000000000000001rem;text-align:center;margin-right:0.5rem;}/*!sc*/
# .kDrakH{background-color:#005d2f;color:#FFFFFF;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:13.2rem;height:10.6rem;border-radius:0.6000000000000001rem;text-align:center;margin-right:0.5rem;}/*!sc*/
# .byqJXC{background-color:#039556;color:#FFFFFF;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:13.2rem;height:10.6rem;border-radius:0.6000000000000001rem;text-align:center;margin-right:0.5rem;}/*!sc*/
# .fujyAN{background-color:#5fa735;color:#FFFFFF;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:13.2rem;height:10.6rem;border-radius:0.6000000000000001rem;text-align:center;margin-right:0.5rem;}/*!sc*/
# data-styled.g1181[id="ReviewAndRatingsstyles__GoRatingBlock-sc-1nxmeoo-12"]{content:"rWAoH,kDrakH,byqJXC,fujyAN,"}/*!sc*/
# .eizHiT{font-size:1.4000000000000001rem;padding-top:0.5rem;padding-bottom:0.5rem;}/*!sc*/
# data-styled.g1182[id="ReviewAndRatingsstyles__ReviewCountTextWrapper-sc-1nxmeoo-14"]{content:"eizHiT,"}/*!sc*/
# .aYkUn{font-size:1.4000000000000001rem;padding-bottom:1rem;}/*!sc*/
# data-styled.g1183[id="ReviewAndRatingsstyles__RatingsCountTextWrapper-sc-1nxmeoo-15"]{content:"aYkUn,"}/*!sc*/
# .dXLJYk{margin-top:1rem;font-size:3rem;}/*!sc*/
# data-styled.g1184[id="ReviewAndRatingsstyles__AvgReviewTextWrapperDiv-sc-1nxmeoo-16"]{content:"dXLJYk,"}/*!sc*/
# .hLCtjf{font-weight:bold;}/*!sc*/
# data-styled.g1185[id="ReviewAndRatingsstyles__AvgReviewTextWrapper-sc-1nxmeoo-17"]{content:"hLCtjf,"}/*!sc*/
# .dhaaZp{font-size:2.6rem;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;line-height:1.1;font-weight:bold;}/*!sc*/
# data-styled.g1186[id="ReviewAndRatingsstyles__TotalReviewTextWrapper-sc-1nxmeoo-18"]{content:"dhaaZp,"}/*!sc*/
# .fBMuEV{padding-right:0.5rem;font-weight:bold;line-height:1;}/*!sc*/
# data-styled.g1187[id="ReviewAndRatingsstyles__ReviewTypeTextWrapper-sc-1nxmeoo-21"]{content:"fBMuEV,"}/*!sc*/
# .eSXHTg{padding-top:unset;width:7rem;}/*!sc*/
# .gAFonm{padding-top:0.30000000000000004rem;width:7rem;}/*!sc*/
# data-styled.g1188[id="ReviewAndRatingsstyles__ProgressBarWrapperDiv-sc-1nxmeoo-22"]{content:"eSXHTg,gAFonm,"}/*!sc*/
# .ejgHUQ{padding-left:1.5rem;color:#777777;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}/*!sc*/
# data-styled.g1189[id="ReviewAndRatingsstyles__ProgressBarCountWrapper-sc-1nxmeoo-24"]{content:"ejgHUQ,"}/*!sc*/
# .jpTwtJ{position:absolute;margin-left:-1rem;width:2.4rem;height:1.2rem;overflow:hidden;}/*!sc*/
# .jpTwtJ::after{content:'';position:absolute;width:1.3rem;height:1.2rem;left:50%;background:white;z-index:9;}/*!sc*/
# data-styled.g1190[id="ReviewAndRatingsstyles__TipUI-sc-1nxmeoo-27"]{content:"jpTwtJ,"}/*!sc*/
# .buRdSk{right:60%;top:-1.2rem;}/*!sc*/
# .buRdSk::after{-webkit-transform:translate(-50%,50%) rotate(45deg);-ms-transform:translate(-50%,50%) rotate(45deg);transform:translate(-50%,50%) rotate(45deg);background:undefined;box-shadow:0 0.1rem 0.4rem rgba(0,0,0,0.25);}/*!sc*/
# data-styled.g1191[id="ReviewAndRatingsstyles__TipPositioning-sc-1nxmeoo-28"]{content:"buRdSk,"}/*!sc*/
# .efbJZS{width:70%;padding-left:0.30000000000000004rem;}/*!sc*/
# data-styled.g1192[id="ReviewAndRatingsstyles__BreakupWrapperDiv-sc-1nxmeoo-29"]{content:"efbJZS,"}/*!sc*/
# .jMtVyk{width:7rem;height:0.8rem;background-color:#EFF3F8;border-radius:0.6000000000000001rem;false;}/*!sc*/
# .fLdKve{width:7rem;height:0.8rem;background-color:#EFF3F8;border-radius:0.6000000000000001rem;position:absolute;}/*!sc*/
# data-styled.g1193[id="ReviewAndRatingsstyles__OverriddenProgressBar-sc-1nxmeoo-30"]{content:"jMtVyk,fLdKve,"}/*!sc*/
# .kLpONj{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-top:0.5rem;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .bisqfG{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-top:0.5rem;false;}/*!sc*/
# data-styled.g1194[id="ReviewAndRatingsstyles__BreakupWrapperContainer-sc-1nxmeoo-31"]{content:"kLpONj,bisqfG,"}/*!sc*/
# .fEXNlP{background-color:#00AA6C;border-radius:0.6000000000000001rem;position:relative;height:0.8rem;width:7rem;}/*!sc*/
# .ksbWVu{background-color:#00AA6C;border-radius:0.6000000000000001rem;position:relative;height:0.8rem;width:3.825rem;}/*!sc*/
# .fmHvxa{background-color:#00AA6C;border-radius:0.6000000000000001rem;position:relative;height:0.8rem;width:1.23rem;}/*!sc*/
# .eOCerC{background-color:#00AA6C;border-radius:0.6000000000000001rem;position:relative;height:0.8rem;width:0.84rem;}/*!sc*/
# ...
#         `${accumulator}<Seo-Faq-Item-Mhotels question="${encodeURIComponent(
#           item.q,
#         )}" answer="${encodeURIComponent(item.a)}"></Seo-Faq-Item-Mhotels>`,
#       '',
#     )}
#     </div>
#   </div>
# `;
#
# const faqItemTemplateMhotels = ({question, answer}) => `
#   <style>
#     :host {
#       display: block;
#     }
#     .qna-component {
#       display: -webkit-box;
#       display: -webkit-flex;
#       display: -ms-flexbox;
#       display: flex;
#       -webkit-flex-direction: column;
#       -ms-flex-direction: column;
#       flex-direction: column;
#       width: 100%;
#       border-bottom: .1rem solid #eaeaea;
#       padding: 1.5rem 0 1.5rem 0;
#     }
#     .question-wrapper {
#       display: flex;
#       // flex-wrap: wrap;
#       width:100%;
#       // align-items: center;
#       margin-bottom:1rem;
#       align-items: flex-start;
#       flex: 6;
#     }
#     .question-icon-wrapper {
#       display: flex;
#       flex-wrap: wrap;
#       width:2.2rem;
#       height:2.2rem;
#       background-color: #eef4fd;
#       border-radius:50%;
#       color: #eee;
#       position:relative;
#       margin-right: .5rem;
#     }
#     .question-icon {
#       display: flex;
#       flex-wrap: wrap;
#       color:#4f525a;
#       position:absolute;
#       top:3px;
#       right:6px;
#       font-size:14px;
#     }
#     .question-text{
#       font-weight: bold;
#       padding-bottom: 1rem;
#       flex: 5.5;
#     }
#     .question-text > p{
#       margin: 0;
#       word-break: break-word;
#     }
#
#     .question-text > p >strong{
#       font-weight:normal;
#     }
#     .answer-text {
#       color: black;
#       flex: 5.5;
#     }
#     .answer-text > p {
#       margin:0!important;
#       word-break: break-word;
#     }
#     .answer-wrapper {
#       display: flex;
#       flex-wrap: wrap;
#       width:100%;
#       flex: 6;
#       // padding-top:10px;
#       // padding-bottom:10px;
#     }
#     .answer-text a{
#       color: #2276e3;
#     font-weight: bold;
#     -webkit-text-decoration: none;
#     text-decoration: none;
#     }
#     .answer-text > ol {
#       padding-left: 2rem!important;
#       margin-top: 1rem!important;
#     }
#   </style>
#   <div class="qna-component" itemscope itemprop="mainEntity" itemtype="https://schema.org/Question">
#     <div class="question-wrapper">
#       <span class="question-icon-wrapper">
#         <span class="question-icon">Q</span>
#       </span>
#       <span itemprop="name" class="question-text">${decodeURIComponent(question)}</span>
#     </div>
#     <div class="answer-wrapper" itemprop="acceptedAnswer" itemscope itemtype="https://schema.org/Answer">
#       <span class="question-icon-wrapper">
#         <span class="question-icon">A</span>
#       </span>
#       <span itemprop="text" class="answer-text">${decodeURIComponent(answer)}</span>
#     </div>
#   </div>
# `;
#
# customElements.define(
#   'seo-faq-item-mhotels',
#   class extends HTMLElement {
#     constructor() {
#       super(); // always call super() first in the constructor.
#       const question = this.getAttribute('question');
#       const answer = this.getAttribute('answer');
#       const shadowRoot = this.attachShadow({mode: 'open'});
#       shadowRoot.innerHTML = faqItemTemplateMhotels({question, answer});
#     }
#   },
# );
#
# customElements.define(
#   'seo-faq-mhotels',
#   class extends HTMLElement {
#     constructor() {
#       super(); // always call super() first in the constructor.
#       const shadowRoot = this.attachShadow({mode: 'open'});
#       const dataProp = this.getAttribute('faqdatakey');
#       const faqHeading = this.getAttribute('faqHeading');
#       if (dataProp) {
#         shadowRoot.innerHTML = faqListTemplateMhotels(
#           window[dataProp].faq_content || [],
#           faqHeading || window[dataProp].faq_heading,
#         );
#       }
#     }
#   },
# );
#
#         </script>
# </span></section></div></div><section class="footer-seostyles__SeoOuterDiv-sc-1ycveqg-0 iXNEUz"><section class="footer-seostyles__SeoFooterWrapper-sc-1ycveqg-4 enFwYa"><div class="footer-seostyles__ColumnDiv-sc-1ycveqg-5 kmZcWw"><p class="footer-seostyles__HeaderPara-sc-1ycveqg-6 isbBTD">Our Products</p><ul class="footer-seostyles__ContentWrapper-sc-1ycveqg-7 fQeGZn"><li><a class="footer-seostyles__PrimaryLink-sc-1ycveqg-8 footer-seostyles__LinkWrapper-sc-1ycveqg-9 lkAtYI hcFFRg" href="//www.goibibo.com/hotels/">Domestic Hotels</a></li><li><a class="footer-seostyles__PrimaryLink-sc-1ycveqg-8 footer-seostyles__LinkWrapper-sc-1ycveqg-9 lkAtYI hcFFRg" href="//www.goibibo.com/hotels-international/">International Hotels</a></li><li><a class="footer-seostyles__PrimaryLink-sc-1ycveqg-8 footer-seostyles__LinkWrapper-sc-1ycveqg-9 lkAtYI hcFFRg" href="//www.goibibo.com/international-flights/">International Flights</a></li><li><a class="footer-seostyles__PrimaryLink-sc-1ycveqg-8 footer-seostyles__LinkWrapper-sc-1ycveqg-9 lkAtYI hcFFRg" href="//www.goibibo.com/bus/">Bus Booking</a></li><li><a class="footer-seostyles__PrimaryLink-sc-1ycveqg-8 footer-seostyles__LinkWrapper-sc-1ycveqg-9 lkAtYI hcFFRg" href="//www.goibibo.com/cars/">Cab Booking</a></li><li><a class="footer-seostyles__PrimaryLink-sc-1ycveqg-8 footer-seostyles__LinkWrapper-sc-1ycveqg-9 lkAtYI hcFFRg" href="//www.goibibo.com/trains/">Train Ticket Booking</a></li><li><a class="footer-seostyles__PrimaryLink-sc-1ycveqg-8 footer-seostyles__LinkWrapper-sc-1ycveqg-9 lkAtYI hcFFRg" href="//www.goibibo.com/routeplanner/">Route Planner</a></li><li><a class="footer-seostyles__PrimaryLink-sc-1ycveqg-8 footer-seostyles__LinkWrapper-sc-1ycveqg-9 lkAtYI hcFFRg" href="//www.goibibo.com/destinations/">Destination Planner</a></li><li><a class="footer-seostyles__PrimaryLink-sc-1ycveqg-8 footer-seostyles__LinkWrapper-sc-1ycveqg-9 lkAtYI hcFFRg" href="//www.goibibo.com/flights/cheap-flights/">Cheap Flights</a></li><li><a class="footer-seostyles__PrimaryLink-sc-1ycveqg-8 footer-seostyles__LinkWrapper-sc-1ycveqg-9 lkAtYI hcFFRg" href="//www.goibibo.com/trains/check-train-running-status/">Train Running Status</a></li><li><a class="footer-seostyles__PrimaryLink-sc-1ycveqg-8 footer-seostyles__LinkWrapper-sc-1ycveqg-9 lkAtYI hcFFRg" href="//www.goibibo.com/trains/check-pnr-status/">Train PNR Status</a></li><li><a class="footer-seostyles__PrimaryLink-sc-1ycveqg-8 footer-seostyles__LinkWrapper-sc-1ycveqg-9 lkAtYI hcFFRg" href="//www.goibibo.com/cars/airport-cabs/">Airport Cabs</a></li><li><a class="footer-seostyles__PrimaryLink-sc-1ycveqg-8 footer-seostyles__LinkWrapper-sc-1ycveqg-9 lkAtYI hcFFRg" href="//www.goibibo.com/hotels/india/">Hotels in India</a></li><li><a class="footer-seostyles__PrimaryLink-sc-1ycveqg-8 footer-seostyles__LinkWrapper-sc-1ycveqg-9 lkAtYI hcFFRg" href="//www.goibibo.com/hotels/hotels-near-me/">Hotels near me</a></li><li><a class="footer-seostyles__PrimaryLink-sc-1ycveqg-8 footer-seostyles__LinkWrapper-sc-1ycveqg-9 lkAtYI hcFFRg" href="//www.goibibo.com/airlines/">Popular Airlines</a></li><li><a class="footer-seostyles__PrimaryLink-sc-1ycveqg-8 footer-seostyles__LinkWrapper-sc-1ycveqg-9 lkAtYI hcFFRg" href="//www.goibibo.com/trains/irctc-forgot-userid/">IRCTC Forgot UserID</a></li><li><a class="footer-seostyles__PrimaryLink-sc-1ycveqg-8 footer-seostyles__LinkWrapper-sc-1ycveqg-9 lkAtYI hcFFRg" href="//www.goibibo.com/trains/irctc-forgot-password/">IRCTC Forgot Password</a></li></ul></div><div class="footer-seostyles__ColumnDiv-sc-1ycveqg-5 kmZcWw"><p class="footer-seostyles__HeaderPara-sc-1ycveqg-6 isbBTD">Company</p><ul class="footer-seostyles__ContentWrapper-sc-1ycveqg-7 fQeGZn"><li><a class="footer-seostyles__PrimaryLink-sc-1ycveqg-8 footer-seostyles__LinkWrapper-sc-1ycveqg-9 lkAtYI hcFFRg" href="//www.goibibo.com/aboutus/">About Us</a></li><li><a class="footer-seostyles__PrimaryLink-sc-1ycveqg-8 footer-seostyles__LinkWrapper-sc-1ycveqg-9 lkAtYI hcFFRg" href="//www.goibibo.com/t ...
# <div id="modal-root"></div>
# <script type="text/javascript">
#             function pageSeen(stage) {
#                 if (!starttime) {
#                     // starttime should be defined on top of the page in the head
#                     return;
#                 }
#                 try {
#                     var endPoint = "//dexter.goibibo.com/common/ping/";
#                     var loc = window.location.pathname;
#                     var timeStamp = (new Date() - starttime) / 1000;
#                     var url = endPoint + "?jsLoaded=" + stage + "&pageseen=" + loc + "&timestamp=" + timeStamp + '&application=avatar' + "&flavour=dweb" + "&docReferer=" + document.referrer + "&timelog=" + new Date().toISOString();
#                     var xhr = new XMLHttpRequest();
#                     xhr.open("GET", url, true);
#                     xhr.withCredentials = true;
#                     xhr.send();
#                 } catch(err) {
#                     console.log(err);
#                 }
#             }
#             // track raw page views
#             pageSeen('FMP');
#         </script>
# <script charset="UTF-8">
#           window.cachedAt="9/5/2022, 5:40:16 PM";
#           window.__initial_state__={"user":{"isLoading":false,"userInfo":{"profile_type":"personal","userid":null},"gocashInfo":null,"isLoggedIn":false,"showLoginPopup":false,"setHeaderLoginClick":false,"loginPopupData":{"loggedinPrice":0,"pageName":""}},"srp":{"hasData":true,"isLoading":false,"displayOverlay":false,"partner":"hotels","srpConfig":{"s":"popularity","cur":"INR","im":true,"filter":{},"seoViewMore":true},"srpData":{"augur_exp":"ih_personalization_v1_all|ih_personalization|ih_personalization","city_meta_info":{"utn":"","pxgrn":0,"altpx":"","pot":[{"oi":"1","ot":"30% or more"},{"oi":"2","ot":"50% or more"},{"oi":"3","ot":"80% or more"}],"sb_msg":"","sb":0,"banner_type":"","scthr":15,"is_ipl":0,"avai_color":["#ff1515","#18a160"],"sim":{"ih_gostays_27sep":{"idx":4}},"am":["Air Conditioning","Airport Transfer (on Demand)","Banquet hall","Bar","Bonfire","Business Services","CCTV surveillance","Caretaker","Conference Room","Contactless check-in","Contactless room service","Daily housekeeping","Dining","Disinfectant wipes","Disinfection","Dispensors for disinfectants","Disposable serveware","Doctor On Call","Face shields","First-aid Services","Free Internet","Front desk","Gloves","Hair nets","Health-Spa","Hospital in the vicinity","Indoor Entertainment","Internet","Laundry Service","Lounge","Luggage assistance","Luggage storage","Masks","Outdoor Activities","Parking Facility","Pool\u002F Beach Towels","Postal Services","Power backup","Restaurant\u002FCoffee Shop","Room Service","Safety authorization certificate","Sanitizers","Sanitizers installed","Shoe covers","Smoking Rooms Available","Spa","Swimming Pool","Travel Assistance","Wheelchair"],"ata":["Alt Acco"],"aty":["Apartment","Hotel","Villa","Aparthotel","Homestay","Cottage","Resort","Hostel","Guest House","BnB","Holiday Homes","Motel","Capsule Hotel","Lodge"],"apu":["Room","Property","Bed"],"grt":["","Exceptional","Good"],"tabs":["Pay At Hotel","Free Cancellation","Star Rating \u003E=3","User Rating \u003E=4","Business Travellers","Daily Steal Deal"],"ac":["bc","gym","int","rest","sp","freeint","nobc","nogym","noint","norest","nosp","nofreeint"],"dsl":[{"n":"Downtown Dubai","ahc":759},{"n":"Dubai Marina","ahc":730},{"n":"Sheikh Zayed Road","ahc":583},{"n":"Palm Jumeirah","ahc":377},{"n":"Jumeirah Beach Residence","ahc":367},{"n":"Deira","ahc":287},{"n":"Jumeirah Village","ahc":243},{"n":"Jumeirah Village","ahc":243},{"n":"Business Bay","ahc":226},{"n":"Bur Dubai","ahc":218},{"n":"Al Barsha","ahc":180},{"n":"Media City","ahc":155},{"n":"Al Sufouh","ahc":72},{"n":"Al Wasl","ahc":59},{"n":"Jumeirah Lakes Towers","ahc":50},{"n":"Dubai Silicon Oasis","ahc":48},{"n":"Jebel Ali","ahc":48},{"n":"Dubai Production City","ahc":37},{"n":"Near Dubai International Airport","ahc":30},{"n":"Umm Suqeim","ahc":27},{"n":"Discovery Gardens","ahc":25},{"n":"International Media Production Zone","ahc":25},{"n":"Dubai Internet City","ahc":22},{"n":"The Villa","ahc":20},{"n":"Motor City","ahc":18},{"n":"Motor City","ahc":18},{"n":"Mudon","ahc":16},{"n":"Al Jaddaf","ahc":15},{"n":"Dubai Festival City","ahc":11},{"n":"Al Bada'a","ahc":11},{"n":"Green Community Village","ahc":10},{"n":"Jumeirah Golf Estates","ahc":9},{"n":"Al Nahda","ahc":9},{"n":"Dubai Sports City","ahc":8},{"n":"Al Quoz","ahc":8},{"n":"Dubai Investments Park","ahc":8},{"n":"Dubai Sports City","ahc":8},{"n":"Emirates Hills","ahc":7},{"n":"Nad Al Sheba","ahc":7},{"n":"International City","ahc":7},{"n":"Al Qusais Industrial Area","ahc":6},{"n":"Nad Al Sheba 1","ahc":6},{"n":"Jumeirah","ahc":6},{"n":"Trade Centre","ahc":6},{"n":"Trade Centre","ahc":6},{"n":"Majan","ahc":5},{"n":"Jumeirah Islands","ahc":5},{"n":"Dubai Marina & Jumeirah Beach Residence","ahc":5},{"n":"Al Hudaiba","ahc":4},{"n":"Garhoud","ahc":4},{"n":"Mirdif","ahc":3},{"n":"The Greens","ahc":3},{"n":"International City Phase(2)","ahc":2},{"n":"Pearl Jumeirah","ahc":2},{"n":"Dubai Logistics City","ahc":2},{"n":"Arabian Ranches","ahc":2},{"n":"The World Islands","ahc" ...
#         </script>
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TJ88JPS" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script type="text/javascript">
#
#     // var _nTimeGC;
#     var loadGTM = function() {
#       <!-- Google Tag Manager -->
#       (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#       'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-TJ88JPS');
#       <!-- End Google Tag Manager -->
#     }
#
#     // var loadGTMCaller = function() {
#     //   _nTimeGC = Date.now();
#     //   var effectiveConnectionType = (
#     //     window.navigator
#     //     && window.navigator.connection
#     //     && window.navigator.connection.effectiveType
#     //   ) ? window.navigator.connection.effectiveType : null;
#     //   window.isSlowConnection = /(2g)/.test(effectiveConnectionType);
#     //   var mediumConnection = /(3g)/.test(effectiveConnectionType);
#
#     //   if (window.isSlowConnection || mediumConnection) {
#     //     setTimeout(function() {
#     //       loadGTM();
#     //     }, 4000);
#     //   } else {
#     //     setTimeout(function() {
#     //       loadGTM();
#     //     }, 2500);
#     //   }
#     // }
#
#     // if(window.requestIdleCallback) {
#     //   window.requestIdleCallback(loadGTMCaller);
#     // } else {
#     //   loadGTMCaller();
#     // }
#
#     loadGTM();
#
#     </script>
# <script type="text/javascript">
#
#         var _nTimeGC;
#         var loadHotjar = function() {
#         var scriptTag = document.createElement("script");
#         scriptTag.setAttribute("src", "https://goibibo.com/flt_hotelsnstatic/lib/hotjar.js");
#         scriptTag.setAttribute("type", "text/javascript");
#         scriptTag.setAttribute("charSet", "UTF-8");
#         document.body.appendChild(scriptTag);
#         }
#
#         var loadHotjarCaller = function() {
#         _nTimeGC = Date.now();
#         var effectiveConnectionType = (
#             window.navigator
#             && window.navigator.connection
#             && window.navigator.connection.effectiveType
#         ) ? window.navigator.connection.effectiveType : null;
#         window.isSlowConnection = /(2g)/.test(effectiveConnectionType);
#         var mediumConnection = /(3g)/.test(effectiveConnectionType);
#
#         if (window.isSlowConnection || mediumConnection) {
#             setTimeout(function() {
#             loadHotjar();
#             }, 4000);
#         } else {
#             setTimeout(function() {
#             loadHotjar();
#             }, 2500);
#         }
#         }
#
#         if(window.requestIdleCallback) {
#         window.requestIdleCallback(loadHotjarCaller);
#         } else {
#         loadHotjarCaller();
#         }
#
#         </script>
# <script defer="" src="https://assets.adobedtm.com/79483c2c7c00/c269e98139c1/launch-adcfac9ffc6d.min.js"></script>
# <script src="/SLnkx8/gc/kC/emJ3/1GSsNZ8-x_/3waLLt6h/GgtVdzEC/KgYYeB/8KTiI" type="text/javascript"></script></body>
# </html>

# %%
# find all the sections with specifiedd class name
cards_data = data.find_all('div', attrs={'class', 'HotelCardstyles__OuterWrapperDiv-sc-1s80tyk-1 jAnSuz'})


# total number of cards
print('Total Number of Cards Found : ', len(cards_data))

# source code of hotel cards
#for card in cards_data:
#    print(card)

for card in cards_data:
    hotel_name = card.find('div', attrs={'class', 'HotelCardstyles__HotelNameWrapperDiv-sc-1s80tyk-22 bwAcIn'})
    hotel_price = card.find('div', attrs={'class', 'HotelCardstyles__CurrentPriceTextWrapper-sc-1s80tyk-39 hSNeLh'})
    print(hotel_name.a.span.text,hotel_price.p.text)
# Out:
# Total Number of Cards Found :  30
# Novotel Deira City Centre 4353
# Delta Hotels by Marriott Jumeirah Beach, Dubai 9234
# Pullman Dubai Creek City Centre 5627
# Hampton by Hilton Dubai Airport 2344
# Royal Ascot Hotel 2887
# Aravi Hotel Deira 2051
# Park Regis Kris Kin Hotel 4869
# JW Marriott Marquis Hotel Dubai 13256
# Gevora Hotel 5783
# Fortune Pearl Hotel Deira 1705
# Citymax Hotel Bur Dubai 2329
# Conrad Dubai 13123
# Emirates Grand Hotel Apartments -Near Burj Khalifa 3120
# Omega Hotel, Bur Dubai 2477
# Tulip Hotel Apartments Bur Dubai 2604
# Novotel World Trade Centre Dubai 6530
# Grand Excelsior Hotel Bur Dubai 2190
# Holiday Inn Bur Dubai Embassy District 2514
# Carlton Tower Dubai Creek 2542
# Howard Johnson by Wyndham Bur Dubai 1806
# Hilton Garden Inn Dubai Al Muraqabat(Deira) 2507
# Hyatt Place Dubai Wasl District 4654
# Raviz Center Point Hotel- Near Burjuman Mall 2592
# Carlton Downtown 3761
# Marco Polo Hotel 1980
# Hilton Garden Inn Bur Dubai Al Mina 3761
# City Seasons Towers Dubai 2886
# Arabian Courtyard Hotel & Spa- In Meena Bazaar 2537
# Orchid Vue Hotel 2925
# Howard Johnson Plaza, Al Rigga 2023

# %%
import pandas as pd

# create a list to store the data
scraped_data = []

for card in cards_data:

    # initialize the dictionary
    card_details = {}

    # get the hotel name
    hotel_name = card.find('div', attrs={'class', 'HotelCardstyles__HotelNameWrapperDiv-sc-1s80tyk-22 bwAcIn'})
    hotel_name = hotel_name.a.span.text

    # get the room price
    room_price = card.find('div', attrs={'class', 'HotelCardstyles__CurrentPriceTextWrapper-sc-1s80tyk-39 hSNeLh'})
    room_price = room_price.p.text

    # add data to the dictionary
    card_details['hotel_name'] = hotel_name
    card_details['room_price'] = room_price

    # append the scraped data to the list
    scraped_data.append(card_details)

# create a data frame from the list of dictionaries
dataFrame = pd.DataFrame.from_dict(scraped_data)

print(dataFrame)

# save the scraped data as CSV file
dataFrame.to_csv('C:\\Users\\Musad\\Desktop\\datascience\\file.csv', index=False)
# Out:
#                                            hotel_name room_price
# 0                           Novotel Deira City Centre       4353
# 1      Delta Hotels by Marriott Jumeirah Beach, Dubai       9234
# 2                     Pullman Dubai Creek City Centre       5627
# 3                     Hampton by Hilton Dubai Airport       2344
# 4                                   Royal Ascot Hotel       2887
# 5                                   Aravi Hotel Deira       2051
# 6                           Park Regis Kris Kin Hotel       4869
# 7                     JW Marriott Marquis Hotel Dubai      13256
# 8                                        Gevora Hotel       5783
# 9                           Fortune Pearl Hotel Deira       1705
# 10                            Citymax Hotel Bur Dubai       2329
# 11                                       Conrad Dubai      13123
# 12  Emirates Grand Hotel Apartments -Near Burj Kha...       3120
# 13                             Omega Hotel, Bur Dubai       2477
# 14                   Tulip Hotel Apartments Bur Dubai       2604
# 15                   Novotel World Trade Centre Dubai       6530
# 16                    Grand Excelsior Hotel Bur Dubai       2190
# 17             Holiday Inn Bur Dubai Embassy District       2514
# 18                          Carlton Tower Dubai Creek       2542
# 19                Howard Johnson by Wyndham Bur Dubai       1806
# 20        Hilton Garden Inn Dubai Al Muraqabat(Deira)       2507
# 21                    Hyatt Place Dubai Wasl District       4654
# 22       Raviz Center Point Hotel- Near Burjuman Mall       2592
# 23                                   Carlton Downtown       3761
# 24                                   Marco Polo Hotel       1980
# 25                Hilton Garden Inn Bur Dubai Al Mina       3761
# 26                          City Seasons Towers Dubai       2886
# 27     Arabian Courtyard Hotel & Spa- In Meena Bazaar       2537
# 28                                   Orchid Vue Hotel       2925
# 29                     Howard Johnson Plaza, Al Rigga       2023
